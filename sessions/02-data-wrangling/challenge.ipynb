# %% [markdown]
# # Session 2 Challenge — Campus Library Usage
#
# **Story:** The library wants to understand study room usage.

# %% [markdown]
# <div style="background: linear-gradient(135deg, #fef3c7, #d1fae5); padding:16px; border-radius:12px; border:1px solid #e5e7eb;">
#   <h3 style="margin-top:0;">Notebook Style Guide</h3>
#   <ul>
#     <li><b>Concept</b> sections explain ideas in plain language.</li>
#     <li><b>Try It</b> cells are for you to edit and run.</li>
#     <li><b>Mini-checks</b> help confirm understanding.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="background:#111827; color:#f9fafb; padding:12px; border-radius:10px;">
#   <b>Memes for Morale</b><br>
#   When your code works on the first try:
#   <pre style="color:#f9fafb;">
# (•_•)  (•_•)>⌐■-■  (⌐■_■)
# </pre>
# </div>

# %%
import pandas as pd

rooms = pd.DataFrame({
    "room": ["A", "A", "B", "B", "C", "C"],
    "day": ["Mon", "Tue", "Mon", "Wed", "Tue", "Thu"],
    "hours": [2, 3, 4, 1, 5, 2],
    "group_size": [3, 2, 4, 1, 5, 2]
})
rooms

# %% [markdown]
# ## Tasks
# 1. Show only rows where `hours` >= 3.
# 2. Compute the average hours by room.
# 3. Sort by `group_size` descending.
# 4. Create a column `hours_per_person`.
# 5. Find the total hours used per day.

# %%
# Your solutions here

# %% [markdown]
# ## Stretch
# - Which room has the highest total hours?
# - Filter for days with total hours >= 5.

# %%
# Stretch solutions here
