# %% [markdown]
# <div style="background-color: #eaf4ff; padding: 15px; border-radius: 10px; border-left: 5px solid #2563eb;">
#
# <h1 style="margin:0;">Titanic Pandas Exercise</h1>
#
# <p style="margin:8px 0 0 0;">
# Use the Titanic passenger dataset to practice core pandas skills: loading data, inspecting structure, filtering rows, grouping, sorting, handling missing values, and creating new columns.
# </p>
#
# <p style="margin:8px 0 0 0;">
# The CSV file is provided for you in this notebook, but you can also check the full dataset and details on Kaggle:
# <a href="https://www.kaggle.com/datasets/yasserh/titanic-dataset?resource=download" target="_blank">Download Titanic dataset (Kaggle)</a>
# </p>
#
# </div>

# %% [markdown]
# **Import pandas as pd.**

# %%
import pandas as pd

# %% [markdown]
# **Read `Titanic-Dataset.csv` as a DataFrame called `titanic`.**

# %%
titanic = pd.read_csv("Titanic-Dataset.csv")

# %% [markdown]
# **Check the first 5 rows of the DataFrame.**

# %%
# Your code here

# %% [markdown]
# **Use `.info()` to inspect the dataset. How many entries are there, and which columns have missing values?**

# %%
# Your code here

# %% [markdown]
# **What is the average age of passengers?**

# %%
# Your code here

# %% [markdown]
# **What is the highest fare paid by any passenger?**

# %%
# Your code here

# %% [markdown]
# **What is the name of the passenger with `PassengerId` 1?**

# %%
# Your code here

# %% [markdown]
# **How old was the passenger named `Heikkinen, Miss. Laina`?**

# %%
# Your code here

# %% [markdown]
# **What is the overall survival rate in the dataset?**

# %%
# Your code here

# %% [markdown]
# **What was the average age of passengers in each passenger class (`Pclass`)?**

# %%
# Your code here

# %% [markdown]
# **How many passengers were in each embarkation port (`Embarked`)?**

# %%
# Your code here

# %% [markdown]
# **How many unique ticket numbers are there?**

# %%
# Your code here

# %% [markdown]
# **Show the top 5 most common passenger ages (ignore missing values).**

# %%
# Your code here

# %% [markdown]
# **How many passengers were traveling alone? Use the idea that a passenger is alone if both `SibSp` and `Parch` are 0.**

# %%
# Your code here

# %% [markdown]
# **Create a new column called `FamilySize` equal to `SibSp + Parch + 1`. Then display the first 5 rows of `SibSp`, `Parch`, and `FamilySize`.**

# %%
# Your code here

# %% [markdown]
# **What is the average fare paid by males versus females?**

# %%
# Your code here

# %% [markdown]
# **How many passenger names contain the word `Miss`?**

# %%
# Your code here

# %% [markdown]
# **What is the survival rate by sex?**

# %%
# Your code here

# %% [markdown]
# **Bonus: Is there a correlation between `Age` and `Fare`?**

# %%
# Your code here

# %% [markdown]
# # Great Job!
