# %% [markdown]
# # Python Practice Exercises
#
# A set of beginner-to-intermediate exercises covering core Python concepts.

# %% [markdown]
# ## Exercise 1: Variables and Data Types
#
# 1. Create variables: `name`, `age`, `is_student`.
# 2. Print them.
# 3. Use `type()` to print their data types.

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: Lists
#
# 1. Create a list `scores` with at least 5 numbers.
# 2. Print first and last item.
# 3. Add a new score.
# 4. Remove one score.
# 5. Print the final list.

# %%
# Your code here

# %% [markdown]
# ## Exercise 3: Dictionaries
#
# 1. Create a dictionary `student` with name, age, grade.
# 2. Print name.
# 3. Add "major".
# 4. Update grade.
# 5. Print final dictionary.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4: Conditionals
#
# Create a variable `score` and print grade (A/B/C/F) using if/elif/else.

# %%
# Your code here

# %% [markdown]
# ## Exercise 5: For Loops
#
# Loop through a list of subjects and print: "I am studying <subject>"

# %%
# Your code here

# %% [markdown]
# ## Exercise 6: While Loop
#
# Count down from 5 to 1 using a while loop, then print "Done!"

# %%
# Your code here

# %% [markdown]
# ## Challenge: Student Grade Analyzer
#
# Create a function `analyze_scores(scores)` that:
#
# - Prints each score
# - Flags scores < 70
# - Marks scores ≥ 90 as excellent
# - Prints the average score

# %%
# Your code here
