# %% [markdown]
# # Session 1 Challenge — Campus Coffee Tracker
#
# **Story:** You are helping the student union track coffee preferences.
#
# **Goal:** Use the Python basics you learned today to analyze a small dataset.

# %% [markdown]
# <div style="background: linear-gradient(135deg, #fef3c7, #d1fae5); padding:16px; border-radius:12px; border:1px solid #e5e7eb;">
#   <h3 style="margin-top:0;">Notebook Style Guide</h3>
#   <ul>
#     <li><b>Concept</b> sections explain ideas in plain language.</li>
#     <li><b>Try It</b> cells are for you to edit and run.</li>
#     <li><b>Mini-checks</b> help confirm understanding.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="background:#111827; color:#f9fafb; padding:12px; border-radius:10px;">
#   <b>Memes for Morale</b><br>
#   When your code works on the first try:
#   <pre style="color:#f9fafb;">
# (•_•)  (•_•)>⌐■-■  (⌐■_■)
# </pre>
# </div>

# %% [markdown]
# ## Data
# We'll work with a small list of coffee orders.

# %%
orders = [
    {"student": "Amina", "drink": "latte", "price": 4.5, "size": "M"},
    {"student": "Jordan", "drink": "black", "price": 2.0, "size": "S"},
    {"student": "Kai", "drink": "latte", "price": 4.5, "size": "L"},
    {"student": "Priya", "drink": "mocha", "price": 5.0, "size": "M"},
    {"student": "Luis", "drink": "black", "price": 2.0, "size": "M"},
]

# %% [markdown]
# ## Tasks
# 1. Print each student's name and their drink.
# 2. Create a list of all unique drinks.
# 3. Count how many orders are size `M`.
# 4. Compute the total revenue.
# 5. Use a list comprehension to get the prices of drinks that cost more than 4.
# 6. Write a function `price_after_discount(price, percent)`.

# %%
# Your solutions here

# %% [markdown]
# ## Stretch
# - Create a dictionary that maps each drink to how many times it appears.
# - Use `filter` or a list comprehension to get only latte orders.

# %%
# Stretch solutions here

# %% [markdown]
# ---
# ### Reflection
# - Which part was easiest?
# - Which part was hardest?
