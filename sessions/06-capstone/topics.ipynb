# %% [markdown]
# # Session 6 — Capstone Mini-Project
#
# **Goal:** Combine everything you've learned.
#
# **Project outline**
# 1. Pick a question
# 2. Load and clean data
# 3. Explore with visuals
# 4. Build a simple model (optional)
# 5. Write a short summary

# %% [markdown]
# <div style="background: linear-gradient(135deg, #fef3c7, #d1fae5); padding:16px; border-radius:12px; border:1px solid #e5e7eb;">
#   <h3 style="margin-top:0;">Notebook Style Guide</h3>
#   <ul>
#     <li><b>Concept</b> sections explain ideas in plain language.</li>
#     <li><b>Try It</b> cells are for you to edit and run.</li>
#     <li><b>Mini-checks</b> help confirm understanding.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="background:#111827; color:#f9fafb; padding:12px; border-radius:10px;">
#   <b>Memes for Morale</b><br>
#   When your code works on the first try:
#   <pre style="color:#f9fafb;">
# (•_•)  (•_•)>⌐■-■  (⌐■_■)
# </pre>
# </div>

# %% [markdown]
# ## Example Questions
# - What factors relate to student performance?
# - How do different majors compare on credits earned?

# %% [markdown]
# ## Suggested Structure
# - `1. Introduction`
# - `2. Data Cleaning`
# - `3. Exploratory Data Analysis`
# - `4. Modeling (optional)`
# - `5. Conclusion`

# %% [markdown]
# ---
# ### Try It Yourself
# Create a project outline for your own dataset.

# %%
# Your outline here
