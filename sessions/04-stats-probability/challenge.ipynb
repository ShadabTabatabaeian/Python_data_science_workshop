# %% [markdown]
# <div style="background-color:#e6f2ff; padding:16px; border-radius:12px; border-left:6px solid #3b82f6;">
# <h2 style="margin-top:0;">Session 4 Challenge — Insurance Costs and Regression</h2>
# </div>

# %% [markdown]
# <div style="background-color:#e6f2ff; padding:16px; border-radius:12px; border-left:6px solid #3b82f6;">
# <h2 style="margin-top:0;">Challenge Goals</h2>
# <ul>
# <li>Practice descriptive statistics with a real dataset</li>
# <li>Use probability ideas to describe subgroups</li>
# <li>Visualize distributions and relationships</li>
# <li>Compute and interpret correlations</li>
# <li>Fit simple and multiple regression models</li>
# <li>Explain results in plain language</li>
# </ul>
# </div>

# %% [markdown]
# ## Dataset Context
#
# In this challenge, you will analyze a health insurance dataset. Your goal is to understand what factors are associated with higher medical charges.
#
# ### Variables
# - `age`: age of primary beneficiary
# - `sex`: insurance contractor gender (`female`, `male`)
# - `bmi`: body mass index
# - `children`: number of dependents covered by insurance
# - `smoker`: smoking status
# - `region`: residential area in the US (`northeast`, `southeast`, `southwest`, `northwest`)
# - `charges`: individual medical costs billed by health insurance
#
# This is a useful social science style dataset because it combines demographic variables, health-related measures, and an important economic outcome: medical costs.

# %% [markdown]
# <div style="background-color:#e6f2ff; padding:16px; border-radius:12px; border-left:6px solid #3b82f6;">
# <h2 style="margin-top:0;">Big Question</h2>
# What factors are most strongly associated with higher insurance charges, and how can probability, statistics, and regression help us answer that question?
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

sns.set_theme(style="whitegrid")

# %% [markdown]
# <div style="background-color:#eaf7ea; padding:16px; border-radius:12px; border-left:6px solid #22c55e;">
# <h2 style="margin-top:0;">Try It Yourself</h2>
# Load <code>insurance.csv</code> into a DataFrame called <code>df</code>. Then display the first 5 rows.
# </div>

# %%
# Your code here

# %% [markdown]
# ## Part 1: Data Exploration

# %% [markdown]
# <div style="background-color:#eaf7ea; padding:16px; border-radius:12px; border-left:6px solid #22c55e;">
# <h2 style="margin-top:0;">Try It Yourself</h2>
# Inspect the dataset using methods such as <code>.info()</code>, <code>.describe()</code>, and <code>.isna().sum()</code>.
# <br><br>
# Answer these questions:
# <ul>
# <li>How many observations are in the dataset?</li>
# <li>Which variables are numeric and which are categorical?</li>
# <li>Are there missing values?</li>
# </ul>
# </div>

# %%
# Your code here

# %% [markdown]
# ## Part 2: Descriptive Statistics

# %% [markdown]
# <div style="background-color:#eaf7ea; padding:16px; border-radius:12px; border-left:6px solid #22c55e;">
# <h2 style="margin-top:0;">Try It Yourself</h2>
# Compute the mean, median, and standard deviation for the following variables:
# <ul>
# <li><code>age</code></li>
# <li><code>bmi</code></li>
# <li><code>charges</code></li>
# </ul>
# Then write 2 or 3 sentences interpreting the typical insurance customer and the spread of medical charges.
# </div>

# %%
# Your code here

# %% [markdown]
# ## Part 3: Probability and Group Comparisons

# %% [markdown]
# <div style="background-color:#eaf7ea; padding:16px; border-radius:12px; border-left:6px solid #22c55e;">
# <h2 style="margin-top:0;">Try It Yourself</h2>
# Create a new variable called <code>high_charge</code> that equals <code>"Yes"</code> if a person's charges are above the median and <code>"No"</code> otherwise.
# <br><br>
# Then compute:
# <ul>
# <li>The overall probability of having a high charge</li>
# <li>The probability of having a high charge given that the person is a smoker</li>
# <li>The probability of having a high charge given that the person is a non-smoker</li>
# </ul>
# What do these probabilities suggest?
# </div>

# %%
# Your code here

# %% [markdown]
# ## Part 4: Distributions and Visualization

# %% [markdown]
# <div style="background-color:#eaf7ea; padding:16px; border-radius:12px; border-left:6px solid #22c55e;">
# <h2 style="margin-top:0;">Try It Yourself</h2>
# Create a histogram of <code>charges</code>. Then answer: is the distribution symmetric, or is it skewed?
# </div>

# %%
# Your code here

# %% [markdown]
# <div style="background-color:#eaf7ea; padding:16px; border-radius:12px; border-left:6px solid #22c55e;">
# <h2 style="margin-top:0;">Try It Yourself</h2>
# Create a box plot comparing <code>charges</code> for smokers and non-smokers.
# <br><br>
# What does the plot suggest about the relationship between smoking and insurance costs?
# </div>

# %%
# Your code here

# %% [markdown]
# <div style="background-color:#eaf7ea; padding:16px; border-radius:12px; border-left:6px solid #22c55e;">
# <h2 style="margin-top:0;">Try It Yourself</h2>
# Create a scatter plot of <code>bmi</code> and <code>charges</code>. Color the points by <code>smoker</code>.
# <br><br>
# What patterns do you notice?
# </div>

# %%
# Your code here

# %% [markdown]
# ## Part 5: Correlation

# %% [markdown]
# <div style="background-color:#eaf7ea; padding:16px; border-radius:12px; border-left:6px solid #22c55e;">
# <h2 style="margin-top:0;">Try It Yourself</h2>
# Compute the correlation matrix for the numeric variables in the dataset.
# <br><br>
# Then answer:
# <ul>
# <li>Which numeric variable has the strongest correlation with <code>charges</code>?</li>
# <li>Is the relationship positive or negative?</li>
# <li>Why should we still be careful about causal interpretation?</li>
# </ul>
# </div>

# %%
# Your code here

# %% [markdown]
# ## Part 6: Simple Linear Regression

# %% [markdown]
# <div style="background-color:#eaf7ea; padding:16px; border-radius:12px; border-left:6px solid #22c55e;">
# <h2 style="margin-top:0;">Try It Yourself</h2>
# Fit a simple linear regression model predicting <code>charges</code> from <code>age</code>.
# <br><br>
# Report:
# <ul>
# <li>the intercept,</li>
# <li>the slope, and</li>
# <li>the R-squared.</li>
# </ul>
# Then interpret the slope in plain language.
# </div>

# %%
# Your code here

# %% [markdown]
# ## Part 7: Multiple Regression

# %% [markdown]
# <div style="background-color:#eaf7ea; padding:16px; border-radius:12px; border-left:6px solid #22c55e;">
# <h2 style="margin-top:0;">Try It Yourself</h2>
# Fit a multiple regression model predicting <code>charges</code> using:
# <ul>
# <li><code>age</code></li>
# <li><code>bmi</code></li>
# <li><code>children</code></li>
# <li><code>smoker</code></li>
# </ul>
# Because <code>smoker</code> is categorical, convert it into a numeric indicator first.
# <br><br>
# After fitting the model, answer:
# <ul>
# <li>Which predictor has the largest coefficient?</li>
# <li>What does the smoking coefficient suggest?</li>
# <li>How does the model's R-squared compare to the simple regression model?</li>
# </ul>
# </div>

# %%
# Your code here

# %% [markdown]
# ## Part 8: Interpretation and Reflection

# %% [markdown]
# <div style="background-color:#eaf7ea; padding:16px; border-radius:12px; border-left:6px solid #22c55e;">
# <h2 style="margin-top:0;">Final Reflection</h2>
# Write a short response that addresses the following:
# <ol>
# <li>Which factors appear most strongly associated with higher insurance charges?</li>
# <li>How did probability, visualization, correlation, and regression each help answer the main question?</li>
# <li>What is one reason we should avoid making strong causal claims from this dataset alone?</li>
# </ol>
# </div>

# %%
# Write your response here as comments or print statements

# %% [markdown]
# ## Stretch Challenge

# %% [markdown]
# <div style="background-color:#eaf7ea; padding:16px; border-radius:12px; border-left:6px solid #22c55e;">
# <h2 style="margin-top:0;">Stretch Challenge</h2>
# Try one of the following:
# <ul>
# <li>Add <code>region</code> and <code>sex</code> to your multiple regression model using dummy variables.</li>
# <li>Create separate regression plots for smokers and non-smokers.</li>
# <li>Investigate whether the relationship between BMI and charges looks different for smokers and non-smokers.</li>
# </ul>
# </div>

# %%
# Stretch work here
