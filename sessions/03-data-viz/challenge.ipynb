# %% [markdown]
# <div style="background-color:#eef6ff; padding:16px; border-radius:12px; border-left:6px solid #2563eb;">
# <h1 style="margin:0;">Mini Project: Cognitive Science Alumni Careers</h1>
# <p style="margin:10px 0 0 0;">Use anonymized alumni data to explore career paths, job titles, and skills among Cognitive Science PhD graduates.</p>
# </div>

# %% [markdown]
# ## Motivation
#
# As Cognitive Science graduate students, many of us wonder: What kinds of jobs can I get after graduation? What skills actually matter? Do people like me go into industry or academia?
#
# Instead of guessing, in this project you will use real data to answer these questions. You are provided with a dataset of UC Merced Cognitive Science PhD alumni. Your goal is to analyze this dataset using Python and generate insights about career paths, skills, and opportunities.

# %% [markdown]
# ## Learning Goals
#
# By the end of this mini-project, you will:
#
# - Practice data cleaning and wrangling using Python (`pandas`)
# - Use descriptive statistics to summarize real-world data
# - Create visualizations with `matplotlib` and `seaborn`
# - Apply basic text analysis methods such as string processing and tokenization
# - Translate data into meaningful career insights

# %% [markdown]
# ## Dataset Description
#
# The dataset includes de-identified information such as:
#
# - Graduation year
# - Career field (industry, academia, etc.)
# - Job titles
# - Skills
# - Employer / workplace
# - Undergraduate background

# %% [markdown]
# ## Final Deliverable
#
# Prepare a report of at least 2 pages that includes:
#
# - Key findings about career paths, roles, and skills
# - At least 3 visualizations
# - A brief interpretation of which skills Cognitive Science students should focus on to succeed in the job market

# %% [markdown]
# ## Setup

# %% [markdown]
# **Task:** Import the libraries you will need for this project.

# %%
# Import pandas, matplotlib, seaborn, and any other libraries you need

# %% [markdown]
# **Task:** Load the alumni dataset into a pandas DataFrame.
#
# Hint: use `pd.read_csv()` and store the result in a variable called `df`.

# %%
# Load the dataset here
# Example: df = pd.read_csv("your_file_name.csv")

# %% [markdown]
# ## Part 1: Data Exploration and Cleaning

# %% [markdown]
# **Tasks:**
#
# - Inspect the dataset with `.head()`, `.info()`, and `.describe()`
# - Check for missing values
# - Clean and standardize key variables (for example, lowercase labels)
#
# **Guiding Questions:**
#
# - How many alumni are in the dataset?
# - What variables are available?
# - Are there inconsistencies in labels?

# %%
# Inspect the first rows of the dataset
# Then examine the columns, data types, and summary information

# %%
# Check for missing values
# Clean or standardize important text columns
# Example ideas: lowercase text, strip whitespace, fix inconsistent labels

# %% [markdown]
# **Write a short interpretation:** What did you learn about the structure and quality of the dataset?

# %%
# Optional: write short notes as Python comments or print statements

# %% [markdown]
# ## Part 2: Career Outcomes

# %% [markdown]
# **Tasks:**
#
# - Compute percentages for career paths using `value_counts(normalize=True)`
# - Create a bar plot of career distribution
#
# **Guiding Questions:**
#
# - What percentage of graduates go into industry vs. academia?
# - Has this changed over time?

# %%
# Calculate the distribution of career paths
# Show both counts and percentages

# %%
# Create a bar plot showing the distribution of career paths

# %%
# Explore whether career outcomes change over time
# You may need to group by graduation year and career field

# %% [markdown]
# ## Part 3: Industry Roles

# %% [markdown]
# **Tasks:**
#
# - Filter for industry roles
# - Create categories for job titles (for example: Data Science, UX, Engineering)
# - Use grouping and counting to summarize the results
# - Visualize the results with a bar chart
#
# **Guiding Questions:**
#
# - What are the most common roles?
# - How dominant is data science?

# %%
# Filter the dataset to keep only industry roles
# Save the result in a new DataFrame if helpful

# %%
# Create a new column that groups job titles into broader categories
# Example categories: data science, UX, engineering, research, other

# %%
# Summarize the role categories and create a visualization

# %% [markdown]
# ## Part 4: Job Titles (Text Analysis)

# %% [markdown]
# **Tasks:**
#
# - Clean job title text (lowercase, remove punctuation)
# - Split text into words
# - Count word frequencies
#
# **Guiding Questions:**
#
# - What words appear most often?
# - Do all roles explicitly say `data scientist`?

# %%
# Clean the job title text
# Consider removing punctuation and converting all text to lowercase

# %%
# Split job titles into words and count the frequency of each word

# %%
# Visualize the most common job title words

# %% [markdown]
# ## Part 5: Skills Analysis

# %% [markdown]
# **Tasks:**
#
# - Split skills into individual items
# - Clean and standardize the text
# - Count frequencies
# - Visualize the top skills with a bar plot
#
# **Guiding Questions:**
#
# - What are the most common skills?
# - Which are technical vs. general skills?

# %%
# Split the skills column into individual skills
# Clean and standardize the entries

# %%
# Count the frequency of each skill
# Display the most common skills

# %%
# Create a bar plot of the top skills

# %% [markdown]
# ## Optional Challenge

# %% [markdown]
# Choose one or more of the following:
#
# - Compare skills across career paths
# - Analyze changes over time
# - Build a simple predictive model for career based on skills and background

# %%
# Optional challenge work goes here

# %% [markdown]
# ## Final Reflection

# %% [markdown]
# Before writing your report, answer these questions:
#
# 1. What career paths are most common among alumni?
# 2. What job roles appear most often?
# 3. What skills seem most valuable in the job market?
# 4. Based on your analysis, what should current Cognitive Science students focus on learning?
