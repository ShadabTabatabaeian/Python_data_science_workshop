# %% [markdown]
# # Session 3 Challenge — Cafeteria Sales Dashboard
#
# **Story:** The cafeteria wants a simple set of visuals for sales.

# %% [markdown]
# <div style="background: linear-gradient(135deg, #fef3c7, #d1fae5); padding:16px; border-radius:12px; border:1px solid #e5e7eb;">
#   <h3 style="margin-top:0;">Notebook Style Guide</h3>
#   <ul>
#     <li><b>Concept</b> sections explain ideas in plain language.</li>
#     <li><b>Try It</b> cells are for you to edit and run.</li>
#     <li><b>Mini-checks</b> help confirm understanding.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="background:#111827; color:#f9fafb; padding:12px; border-radius:10px;">
#   <b>Memes for Morale</b><br>
#   When your code works on the first try:
#   <pre style="color:#f9fafb;">
# (•_•)  (•_•)>⌐■-■  (⌐■_■)
# </pre>
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sales = pd.DataFrame({
    "item": ["Pizza", "Burger", "Salad", "Pizza", "Salad", "Burger"],
    "day": ["Mon", "Mon", "Mon", "Tue", "Tue", "Tue"],
    "sales": [30, 22, 18, 35, 20, 25]
})

sales

# %% [markdown]
# ## Tasks
# 1. Create a bar chart of total sales by item.
# 2. Create a line plot of sales by day (aggregate first).
# 3. Create a histogram of sales values.

# %%
# Your solutions here

# %% [markdown]
# ## Stretch
# - Add labels and titles to all charts.
# - Use a seaborn color palette.

# %%
# Stretch solutions here
